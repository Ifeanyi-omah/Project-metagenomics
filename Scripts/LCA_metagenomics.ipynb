# %%
# %matplotlib inline
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import gridspec
import matplotlib.patheffects as path_effects

import os,glob,copy
import numpy as np
import squarify

typeface='Helvetica Neue'
mpl.rcParams['mathtext.fontset']='custom'
mpl.rcParams['font.sans-serif']=typeface
mpl.rcParams['mathtext.default']='sf'
mpl.rcParams['axes.labelweight']=300
mpl.rcParams['font.family']=typeface
mpl.rcParams['font.size']=22

base_path='/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Metdata_senzor_project.csv' ## where contig_quality and contig folders sit

metadata={}
with open(base_path, 'r') as f:  # Use 'with' to open the file safely
    for line_num, line in enumerate(f):
        l = line.strip().split(',')  # Remove '\r\n' and split by comma
        if line_num == 0:  # Assuming the first line is the header
            header = l
        else:
            metadata[l[0]] = {header[i]: l[i].strip() for i in range(len(l))}  # Safely strip spaces

# %%
import os
import pandas as pd
from Bio import SeqIO  # To parse FASTA files

# Define file paths
csv_target_directory = '/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/'
final_csv_path = os.path.join(csv_target_directory, '1total_updated_final_merged_contig_read_counts.csv')
fasta_file_path = "/Volumes/aine_store/SENZOR_project/Blast_databse/NCBI_virus_reference.fa"  # Update this with the path to your TXT file

# Step 1: Parse the FASTA file to extract accession IDs, family, genus, and virus names
accession2info = {}
for record in SeqIO.parse(fasta_file_path, "fasta"):
    header = record.description
    # Split the header based on the pipe symbol
    accession_id = header.split('|')[0].split('.')[0].strip()  # Accession ID without version (e.g., NC_086348 from NC_086348.1)
    family = header.split('|')[1].strip()  # Family (e.g., 'Phenuiviridae')
    genus = header.split('|')[2].strip()  # Genus (e.g., 'Phlebovirus')
    virus_name = header.split('|')[3].strip()  # Virus name (e.g., 'Frijoles phlebovirus')
    
    # Store the family, genus, and virus name in a dictionary, mapping by the accession ID without version number
    accession2info[accession_id] = {'family': family, 'genus': genus, 'name': virus_name}

# Step 2: Load the CSV file
df = pd.read_csv(final_csv_path)

# Step 3: Remove the version numbers from the 'subject' column in the CSV (if present)
df['subject'] = df['subject'].str.split('.').str[0]

# Step 4: Update the CSV with family, genus, and virus names based on the 'subject' column
df['family'] = df['subject'].map(lambda acc: accession2info.get(acc, {}).get('family'))  # Create or update 'family' column
df['genus'] = df['subject'].map(lambda acc: accession2info.get(acc, {}).get('genus'))  # Create or update 'genus' column
df['name'] = df['subject'].map(lambda acc: accession2info.get(acc, {}).get('name'))  # Update the 'name' column

# Step 5: Save the updated CSV to a new file
updated_csv_path = os.path.join(csv_target_directory, '1complete_final_merged_contig_read_counts_with_family_genus_names.csv')
df.to_csv(updated_csv_path, index=False)

print(f"Updated CSV with family, genus, and virus names saved at: {updated_csv_path}")
# Out:
# Updated CSV with family, genus, and virus names saved at: /Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/1complete_final_merged_contig_read_counts_with_family_genus_names.csv

# %%
df =pd.read_csv("/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/updated_final_merged_contig_read_counts_with_genus_and_names.csv")

df.head(100)
# Out:
#              sample  contig_name  contig_length  read_count subject  \
# 0   AIAMACAT001_S69       k141_0            226           2     NaN
# 1   AIAMACAT001_S69  k141_176892            268          10     NaN
# 2   AIAMACAT001_S69  k141_235855            231           2     NaN
# 3   AIAMACAT001_S69   k141_58964            324           7     NaN
# 4   AIAMACAT001_S69  k141_117928            281           4     NaN
# ..              ...          ...            ...         ...     ...
# 95  AIAMACAT001_S69  k141_235869            285           6     NaN
# 96  AIAMACAT001_S69  k141_412760            384           7     NaN
# 97  AIAMACAT001_S69  k141_117939            244           2     NaN
# 98  AIAMACAT001_S69      k141_13            258           4     NaN
# 99  AIAMACAT001_S69  k141_235870            231          11     NaN
#
#     percent_identity  alignment_length  mismatches  gap_opens  q_start  ...  \
# 0                NaN               NaN         NaN        NaN      NaN  ...
# 1                NaN               NaN         NaN        NaN      NaN  ...
# 2                NaN               NaN         NaN        NaN      NaN  ...
# 3                NaN               NaN         NaN        NaN      NaN  ...
# 4                NaN               NaN         NaN        NaN      NaN  ...
# ..               ...               ...         ...        ...      ...  ...
# 95               NaN               NaN         NaN        NaN      NaN  ...
# 96               NaN               NaN         NaN        NaN      NaN  ...
# 97               NaN               NaN         NaN        NaN      NaN  ...
# 98               NaN               NaN         NaN        NaN      NaN  ...
# 99               NaN               NaN         NaN        NaN      NaN  ...
#
#     taxid_blast  blasted  taxon_group_blast  taxid_curated   rdrp  name  \
# 0           NaN     True            Viruses            NaN  False   NaN
# 1           NaN     True            Viruses            NaN  False   NaN
# 2           NaN     True            Viruses            NaN  False   NaN
# 3           NaN     True            Viruses            NaN  False   NaN
# 4           NaN     True            Viruses            NaN  False   NaN
# ..          ...      ...                ...            ...    ...   ...
# 95          NaN     True            Viruses            NaN  False   NaN
# 96          NaN     True            Viruses            NaN  False   NaN
# 97          NaN     True            Viruses            NaN  False   NaN
# 98          NaN     True            Viruses            NaN  False   NaN
# 99          NaN     True            Viruses            NaN  False   NaN
#
#     segment  curated taxon_group  genus
# 0       NaN     True     Viruses    NaN
# 1       NaN     True     Viruses    NaN
# 2       NaN     True     Viruses    NaN
# 3       NaN     True     Viruses    NaN
# 4       NaN     True     Viruses    NaN
# ..      ...      ...         ...    ...
# 95      NaN     True     Viruses    NaN
# 96      NaN     True     Viruses    NaN
# 97      NaN     True     Viruses    NaN
# 98      NaN     True     Viruses    NaN
# 99      NaN     True     Viruses    NaN
#
# [100 rows x 29 columns]

# %%
import os
import pandas as pd
from ete3 import NCBITaxa

# Initialize NCBI taxonomy object
ncbi = NCBITaxa()

# Define the path to the virus_accession2taxid.txt file
accession2taxid_file = "/Volumes/aine_store/SENZOR_project/Blast_databse/virus_accession2taxid.txt"

# Load the virus_accession2taxid.txt file into a dictionary
accession2taxid = {}
with open(accession2taxid_file, 'r') as f:
    for line in f:
        accession, taxid = line.strip().split('\t')  # Assuming it's tab-delimited
        accession2taxid[accession] = int(taxid)  # Store taxid as an integer

# Load your CSV file
csv_file = '/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/1complete_final_merged_contig_read_counts_with_family_genus_names.csv'  # Update with your actual file path
df = pd.read_csv(csv_file)

# Function to calculate the number of aligned bases (alignment_length * percent_identity)
def aligned_bases(row):
    if pd.notna(row['alignment_length']) and pd.notna(row['percent_identity']):
        return row['alignment_length'] * (row['percent_identity'] / 100)
    return 0

# Apply the aligned_bases function to all rows to compute the aligned bases for each hit
df['aligned_bases'] = df.apply(aligned_bases, axis=1)

# Identify the best BLAST hit (with the highest aligned bases) for each contig
df['best_hit'] = df.groupby('contig_name')['aligned_bases'].transform(max)

# Filter hits that are within the threshold:
# aligned_bases >= best_hit - mismatches
def is_valid_hit(row):
    if pd.notna(row['best_hit']) and pd.notna(row['mismatches']):
        threshold = row['best_hit'] - row['mismatches']
        return row['aligned_bases'] >= threshold
    return False

df['valid_hit'] = df.apply(is_valid_hit, axis=1)

# Function to compute the LCA of taxonomic IDs using NCBI taxonomy
def compute_lca(taxids):
    if len(taxids) == 0:
        return None
    try:
        taxid_lca = ncbi.get_topology(taxids).get_common_ancestor(taxids).name
        return taxid_lca
    except:
        return None

# Remove version numbers from the 'subject' column (everything after the first dot)
df['subject'] = df['subject'].str.split('.').str[0]

# Map subjects to taxonomic IDs using the accession2taxid dictionary
df['taxid_blast'] = df['subject'].map(accession2taxid)

# Group valid hits by contig_name and calculate the LCA
df['taxid_curated'] = df.groupby('contig_name')['taxid_blast'].transform(lambda x: compute_lca(x.dropna().tolist()))

# Save the updated dataframe to a new CSV file
output_csv_file = '/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/11complete_final_merged_contig_read_counts_with_family_genus_names.csv'  # Update with your desired output file path
df.to_csv(output_csv_file, index=False)

print(f"Updated CSV saved at: {output_csv_file}")
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /var/folders/xt/vz8fznds4hdbfcxyds95mtp00000gp/T/ipykernel_36745/1566266819.py:61: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['taxid_curated'] = df.groupby('contig_name')['taxid_blast'].transform(lambda x: compute_lca(x.dropna().tolist()))
# Updated CSV saved at: /Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/11complete_final_merged_contig_read_counts_with_family_genus_names.csv

# %%
import os
import pandas as pd
from Bio import SeqIO  # To parse FASTA files

# Define file paths
csv_target_directory = '/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/'
final_csv_path = os.path.join(csv_target_directory, '11complete_final_merged_contig_read_counts_with_family_genus_names.csv')
fasta_file_path = "/Volumes/aine_store/SENZOR_project/Blast_databse/NCBI_virus_reference.fa"  # Update this with the path to your FASTA file

# Step 1: Parse the FASTA file to extract accession IDs, family, genus, and virus names
accession2info = {}
for record in SeqIO.parse(fasta_file_path, "fasta"):
    header = record.description
    # Split the header based on the pipe symbol
    accession_id = header.split('|')[0].split('.')[0].strip()  # Accession ID without version (e.g., NC_086348 from NC_086348.1)
    family = header.split('|')[1].strip()  # Family (e.g., 'Phenuiviridae')
    genus = header.split('|')[2].strip()  # Genus (e.g., 'Phlebovirus')
    virus_name = header.split('|')[3].strip()  # Virus name (e.g., 'Frijoles phlebovirus')
    
    # Store the family, genus, and virus name in a dictionary, mapping by the accession ID without version number
    accession2info[accession_id] = {'family': family, 'genus': genus, 'name': virus_name}

# Step 2: Load the CSV file
df = pd.read_csv(final_csv_path)

# Step 3: Remove the version numbers from the 'subject' column in the CSV (if present)
df['subject'] = df['subject'].str.split('.').str[0]

# Step 4: Mark 'dark contigs' for contigs with no BLAST hits (no match in accession2info)
df['dark_contig'] = df['subject'].apply(lambda acc: 'Yes' if acc not in accession2info else 'No')

# Step 5: Save the updated CSV to a new file
output_csv_file = os.path.join(csv_target_directory, 'LCA_complete_final_merged_contig_read_counts_with_dark_contigs.csv')
df.to_csv(output_csv_file, index=False)

print(f"Updated CSV with dark contigs saved at: {output_csv_file}")
# Out:
# Updated CSV with dark contigs saved at: /Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/LCA_complete_final_merged_contig_read_counts_with_dark_contigs.csv

# %%
import os
import pandas as pd

# Define the paths
csv_target_directory = '/Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/'
final_csv_path = os.path.join(csv_target_directory, 'updated_final_merged_contig_read_counts_with_genus_and_names.csv')
accession2taxid_file = "/Volumes/aine_store/SENZOR_project/Blast_databse/virus_accession2taxid.txt"

# Load the virus_accession2taxid.txt file into a dictionary
accession2taxid = {}
with open(accession2taxid_file, 'r') as f:
    for line in f:
        accession, taxid = line.strip().split('\t')  # Assuming it's tab-delimited
        accession2taxid[accession] = taxid

# Load the final_merged_contig_read_counts.csv
df = pd.read_csv(final_csv_path)

# Remove version numbers from the 'subject' column (everything after the first dot)
df['subject'] = df['subject'].str.split('.').str[0]

# Update the 'taxid_curated' column in the CSV based on the 'subject' column matching with the accession IDs
df['taxid_curated'] = df['subject'].map(accession2taxid)

# Save the updated dataframe back to CSV
updated_csv_path = os.path.join(csv_target_directory, '1total_updated_final_merged_contig_read_counts.csv')
df.to_csv(updated_csv_path, index=False)

print(f"Updated CSV saved at: {updated_csv_path}")
# Out:
# Updated CSV saved at: /Volumes/aine_store/SENZOR_project/SPlited_SENSOR_porject/IDseq/Scylla_merged_csv_files/1total_updated_final_merged_contig_read_counts.csv

# %%
import os
import pandas as pd

# Define the directory where the CSV files are located
csv_target_directory = '/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/'

# List to store dataframes for merging
csv_dataframes = []

# Loop through each CSV file in the target directory
for file_name in os.listdir(csv_target_directory):
    if file_name.endswith('_final_merged_blast_contig_read_counts.csv'):  # Ensure it matches the correct CSV files
        full_file_path = os.path.join(csv_target_directory, file_name)
        
        # Read the CSV file and append to the list of dataframes
        df = pd.read_csv(full_file_path)
        csv_dataframes.append(df)

# Merge all CSV dataframes into one, ignoring the extra headers
merged_csv = pd.concat(csv_dataframes, ignore_index=True)

# Save the merged dataframe into a new CSV file
final_csv_path = os.path.join(csv_target_directory, 'final_merged_contig_read_counts.csv')
merged_csv.to_csv(final_csv_path, index=False)

print(f"Final merged CSV saved at: {final_csv_path}")
# Out:
# /var/folders/xt/vz8fznds4hdbfcxyds95mtp00000gp/T/ipykernel_36745/2817090417.py:16: DtypeWarning: Columns (4,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_file_path)
# /var/folders/xt/vz8fznds4hdbfcxyds95mtp00000gp/T/ipykernel_36745/2817090417.py:16: DtypeWarning: Columns (4,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_file_path)
# Final merged CSV saved at: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/final_merged_contig_read_counts.csv

# %%
import os
import shutil

# Define the base path and target directory
base_path = '/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed'
folders = ['CAT_fastq', 'CHICKEN_fastq', 'DOG_fastq', 'GOAT_fastq', 'LIZARD_fastq', 'PIG_fastq', 'SHEEP_fastq']
target_directory = '/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/'

# Create the target directory if it doesn't exist
os.makedirs(target_directory, exist_ok=True)

# Traverse each folder and copy the relevant CSV files
for folder in folders:
    folder_path = os.path.join(base_path, folder)
    
    # Walk through all subdirectories in the folder
    for root, dirs, files in os.walk(folder_path):
        # Check if the current path contains the "assemblies/viruses" folder
        if 'assemblies/viruses' in root:
            # Loop through the files and find the desired CSV files
            for file in files:
                if file.endswith('_final_merged_blast_contig_read_counts.csv'):
                    # Construct full file path
                    full_file_path = os.path.join(root, file)
                    # Copy file to the target directory
                    shutil.copy(full_file_path, target_directory)
                    print(f"Copied: {full_file_path} to {target_directory}")

print("Finished copying files.")
# Out:
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CAT_fastq/AIAMACAT001_S69/assemblies/viruses/AIAMACAT001_S69_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CAT_fastq/SEZONOWIFCAT001_S34/assemblies/viruses/SEZONOWIFCAT001_S34_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/AINWZCHICKEN001_S56/assemblies/viruses/AINWZCHICKEN001_S56_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/AINWZCHICKEN002_S57/assemblies/viruses/AINWZCHICKEN002_S57_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/SEZOOWOGCHICKEN001_S35/assemblies/viruses/SEZOOWOGCHICKEN001_S35_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AIAMADOG001_S40/assemblies/viruses/AIAMADOG001_S40_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AIMGLDOG001_S59/assemblies/viruses/AIMGLDOG001_S59_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG001_S37/assemblies/viruses/AINWZDOG001_S37_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG002_S38/assemblies/viruses/AINWZDOG002_S38_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG003_S39/assemblies/viruses/AINWZDOG003_S39_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG009_S20/assemblies/viruses/SEZONOWDOG009_S20_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG012_S10/assemblies/viruses/SEZONOWDOG012_S10_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG01_S7/assemblies/viruses/SEZONOWDOG01_S7_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWIFDOG009_S1/assemblies/viruses/SEZONOWIFDOG009_S1_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG002_S4/assemblies/viruses/SEZONOWISDOG002_S4_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG008_S14/assemblies/viruses/SEZONOWISDOG008_S14_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG015_S13/assemblies/viruses/SEZONOWISDOG015_S13_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOGOO1_S19/assemblies/viruses/SEZONOWISDOGOO1_S19_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG001_S6/assemblies/viruses/SEZONOWOGDOG001_S6_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG002_S5/assemblies/viruses/SEZONOWOGDOG002_S5_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG004_S12/assemblies/viruses/SEZONOWOGDOG004_S12_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG00_S2/assemblies/viruses/SEZONOWOGDOG00_S2_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG010_S3/assemblies/viruses/SEZONOWOGDOG010_S3_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG013_S18/assemblies/viruses/SEZONOWOGDOG013_S18_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG014_S21/assemblies/viruses/SEZONOWOGDOG014_S21_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG016_S23/assemblies/viruses/SEZONOWOGDOG016_S23_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG017_S22/assemblies/viruses/SEZONOWOGDOG017_S22_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWISDOG003_S11/assemblies/viruses/SEZOOWISDOG003_S11_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG003_S17/assemblies/viruses/SEZOOWOGDOG003_S17_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG005_S15/assemblies/viruses/SEZOOWOGDOG005_S15_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG006_S16/assemblies/viruses/SEZOOWOGDOG006_S16_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG011_S8/assemblies/viruses/SEZOOWOGDOG011_S8_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG019_S9/assemblies/viruses/SEZOOWOGDOG019_S9_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT001_S48/assemblies/viruses/AIAMAGOAT001_S48_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT002_S49/assemblies/viruses/AIAMAGOAT002_S49_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT003_S50/assemblies/viruses/AIAMAGOAT003_S50_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT004_S51/assemblies/viruses/AIAMAGOAT004_S51_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIMGLGOAT001_S60/assemblies/viruses/AIMGLGOAT001_S60_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIMGLGOAT002_S61/assemblies/viruses/AIMGLGOAT002_S61_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT001_S41/assemblies/viruses/AINWZGOAT001_S41_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT002_S42/assemblies/viruses/AINWZGOAT002_S42_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT004_S44/assemblies/viruses/AINWZGOAT004_S44_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT005_S45/assemblies/viruses/AINWZGOAT005_S45_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT006_S46/assemblies/viruses/AINWZGOAT006_S46_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT007_S68/assemblies/viruses/SEZONOWIFGOAT007_S68_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT011_S29/assemblies/viruses/SEZONOWIFGOAT011_S29_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT012_S30/assemblies/viruses/SEZONOWIFGOAT012_S30_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWISGOAT008_S25/assemblies/viruses/SEZONOWISGOAT008_S25_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWOGGOAT015_S28/assemblies/viruses/SEZONOWOGGOAT015_S28_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWOGGOAT018_S66/assemblies/viruses/SEZONOWOGGOAT018_S66_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZOOWISUGOAT002_S27/assemblies/viruses/SEZOOWISUGOAT002_S27_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/LIZARD_fastq/AINWZLIZARD001_S58/assemblies/viruses/AINWZLIZARD001_S58_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/LIZARD_fastq/SEZONOWISLIZARD001_S36/assemblies/viruses/SEZONOWISLIZARD001_S36_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AIAMAPIG001_S63/assemblies/viruses/AIAMAPIG001_S63_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AIAMAPIG002_S64/assemblies/viruses/AIAMAPIG002_S64_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AINWZPIG001_S62/assemblies/viruses/AINWZPIG001_S62_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIAMASHEEP001_S53/assemblies/viruses/AIAMASHEEP001_S53_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIAMASHEEP002_S54/assemblies/viruses/AIAMASHEEP002_S54_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIMASHEEP003_S55/assemblies/viruses/AIMASHEEP003_S55_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIMUZSHEEP001_S52/assemblies/viruses/AIMUZSHEEP001_S52_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWIFSHEEP001_S33/assemblies/viruses/SEZONOWIFSHEEP001_S33_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWIFSHEEP002_S31/assemblies/viruses/SEZONOWIFSHEEP002_S31_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Copied: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWISSHEEP001_S32/assemblies/viruses/SEZONOWISSHEEP001_S32_final_merged_blast_contig_read_counts.csv to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/merged_csv_files/
# Finished copying files.

# %%
import os
import shutil

# Define the base path and target directory
base_path = '/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed'
folders = ['CAT_fastq', 'CHICKEN_fastq', 'DOG_fastq', 'GOAT_fastq', 'LIZARD_fastq', 'PIG_fastq', 'SHEEP_fastq']
target_directory = '/Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/'

# Create the target directory if it doesn't exist
os.makedirs(target_directory, exist_ok=True)

# Traverse each folder and copy the relevant megahit_assembled_contigs.fa files
for folder in folders:
    folder_path = os.path.join(base_path, folder)
    
    # Walk through all subdirectories in the folder
    for root, dirs, files in os.walk(folder_path):
        # Check if the current path contains the "assemblies/viruses" folder
        if 'assemblies/viruses' in root:
            # Extract the sample name from the folder path
            sample_name = root.split(os.sep)[-3]  # Assuming the sample folder is two levels above "viruses"
            
            # Loop through the files and find the "megahit_assembled_contigs.fa"
            for file in files:
                if file == 'megahit_assembled_contigs.fa':
                    # Construct full file path
                    full_file_path = os.path.join(root, file)
                    
                    # Create a new filename with the sample name prefixed
                    new_filename = f"{sample_name}_megahit_assembled_contigs.fa"
                    new_file_path = os.path.join(target_directory, new_filename)
                    
                    # Copy file to the target directory with the new name
                    shutil.copy(full_file_path, new_file_path)
                    print(f"Copied and renamed: {full_file_path} to {new_file_path}")

print("Finished copying and renaming megahit contigs files.")
# Out:
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CAT_fastq/AIAMACAT001_S69/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMACAT001_S69_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CAT_fastq/SEZONOWIFCAT001_S34/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFCAT001_S34_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/AINWZCHICKEN001_S56/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZCHICKEN001_S56_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/AINWZCHICKEN002_S57/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZCHICKEN002_S57_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/CHICKEN_fastq/SEZOOWOGCHICKEN001_S35/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGCHICKEN001_S35_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AIAMADOG001_S40/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMADOG001_S40_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AIMGLDOG001_S59/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIMGLDOG001_S59_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG001_S37/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZDOG001_S37_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG002_S38/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZDOG002_S38_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/AINWZDOG003_S39/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZDOG003_S39_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG009_S20/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWDOG009_S20_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG012_S10/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWDOG012_S10_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWDOG01_S7/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWDOG01_S7_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWIFDOG009_S1/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFDOG009_S1_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG002_S4/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISDOG002_S4_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG008_S14/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISDOG008_S14_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOG015_S13/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISDOG015_S13_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWISDOGOO1_S19/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISDOGOO1_S19_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG001_S6/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG001_S6_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG002_S5/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG002_S5_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG004_S12/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG004_S12_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG00_S2/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG00_S2_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG010_S3/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG010_S3_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG013_S18/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG013_S18_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG014_S21/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG014_S21_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG016_S23/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG016_S23_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZONOWOGDOG017_S22/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGDOG017_S22_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWISDOG003_S11/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWISDOG003_S11_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG003_S17/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGDOG003_S17_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG005_S15/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGDOG005_S15_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG006_S16/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGDOG006_S16_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG011_S8/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGDOG011_S8_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/DOG_fastq/SEZOOWOGDOG019_S9/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWOGDOG019_S9_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/1GOAT_fastq/2GOAT_fastq2/AINWZGOAT004_S44/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT004_S44_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/1GOAT_fastq/2GOAT_fastq2/SEZONOWIFGOAT007_S68/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFGOAT007_S68_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT001_S48/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAGOAT001_S48_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT002_S49/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAGOAT002_S49_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT003_S50/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAGOAT003_S50_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIAMAGOAT004_S51/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAGOAT004_S51_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIMGLGOAT001_S60/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIMGLGOAT001_S60_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AIMGLGOAT002_S61/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIMGLGOAT002_S61_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT001_S41/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT001_S41_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT002_S42/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT002_S42_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT004_S44/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT004_S44_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT005_S45/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT005_S45_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/AINWZGOAT006_S46/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZGOAT006_S46_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT007_S68/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFGOAT007_S68_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT011_S29/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFGOAT011_S29_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWIFGOAT012_S30/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFGOAT012_S30_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWISGOAT008_S25/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISGOAT008_S25_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWOGGOAT015_S28/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGGOAT015_S28_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZONOWOGGOAT018_S66/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWOGGOAT018_S66_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/GOAT_fastq/SEZOOWISUGOAT002_S27/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZOOWISUGOAT002_S27_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/LIZARD_fastq/AINWZLIZARD001_S58/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZLIZARD001_S58_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/LIZARD_fastq/SEZONOWISLIZARD001_S36/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISLIZARD001_S36_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AIAMAPIG001_S63/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAPIG001_S63_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AIAMAPIG002_S64/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMAPIG002_S64_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/PIG_fastq/AINWZPIG001_S62/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AINWZPIG001_S62_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIAMASHEEP001_S53/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMASHEEP001_S53_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIAMASHEEP002_S54/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIAMASHEEP002_S54_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIMASHEEP003_S55/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIMASHEEP003_S55_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/AIMUZSHEEP001_S52/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/AIMUZSHEEP001_S52_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWIFSHEEP001_S33/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFSHEEP001_S33_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWIFSHEEP002_S31/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWIFSHEEP002_S31_megahit_assembled_contigs.fa
# Copied and renamed: /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/SHEEP_fastq/SEZONOWISSHEEP001_S32/assemblies/viruses/megahit_assembled_contigs.fa to /Volumes/aine_store/SENZOR_project/1stBatch_senzor/Scylla_completed/megahit_contigs/SEZONOWISSHEEP001_S32_megahit_assembled_contigs.fa
# Finished copying and renaming megahit contigs files.
